# %%
import matplotlib.pyplot as plt

# Simple plot to test matplotlib installation
# This should display a simple line plot
# If only one argument is given, it is interpreted as y values and x values are auto-generated as [0, 1, 2, ...]
plt.plot([1, 2, 3, 4])
plt.show()

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
plt.plot(x, y)
plt.show()
